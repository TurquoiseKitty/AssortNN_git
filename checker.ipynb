# %%
from test import MNL_specialCheck

MNL_specialCheck(
    utility_file_path = "EXP1_datasets/MNL/NProd_20/utils.npy", 
    model_path = "logs/EXP1_MNL_20_VanillaMNL_LARGE/EXP1_MNL_20_VanillaMNL_LARGE_last.pth",
    N_prod = 20)
# Out:
# actual probabilities:
# [0.20736695 0.10233781 0.03375974 0.05394357 0.05408319 0.02183731
#  0.01465247 0.06796076 0.01726706 0.02444125 0.0176306  0.03243546
#  0.05973167 0.02535923 0.00604763 0.06272864 0.07110145 0.022645
#  0.09527906 0.00939115]
# predicted probs:
# tensor([0.2005, 0.1042, 0.0331, 0.0542, 0.0539, 0.0226, 0.0147, 0.0669, 0.0178,
#         0.0247, 0.0179, 0.0336, 0.0614, 0.0256, 0.0072, 0.0625, 0.0716, 0.0223,
#         0.0955, 0.0098], device='cuda:0', grad_fn=<SelectBackward0>)

# %%
from test import Accu_Plot

Accu_Plot(log_path = 'logs/EXP1_MC_20_VanillaMNL_LARGE')

# %%
from test import Accu_Plot

Accu_Plot(log_path = 'logs/EXP1_MC_20_AssortmentNN_LARGE')

# %%
from test import KL_loss_check

KL_loss_check(
    training_yaml_path = "configs\EXP1_NP_20_VanillaMNL_LARGE.yaml", 
    model_name = "EXP1_NP_20_VanillaMNL_LARGE" )
# Out:
# Test KL loss:  {'KL_loss': tensor(1.7046, device='cuda:0', grad_fn=<DivBackward1>)}
# Best possible KL loss:  {'KL_loss': tensor(1.4227, device='cuda:0')}
# Silly prediction KL loss:  {'KL_loss': tensor(2.5057, device='cuda:0')}

# %%
from test import KL_loss_check

KL_loss_check(
    training_yaml_path = "configs\EXP1_NP_20_AssortmentNN_LARGE.yaml", 
    model_name = "EXP1_NP_20_AssortmentNN_LARGE" )
# Out:
# Test KL loss:  {'KL_loss': tensor(1.4898, device='cuda:0', grad_fn=<DivBackward1>)}
# Best possible KL loss:  {'KL_loss': tensor(1.4227, device='cuda:0')}
# Silly prediction KL loss:  {'KL_loss': tensor(2.4986, device='cuda:0')}

# %%
from test import KL_loss_check

KL_loss_check(
    training_yaml_path = "configs\EXP1_RF_20_VanillaMNL_LARGE.yaml", 
    model_name = "EXP1_RF_20_VanillaMNL_LARGE" )
# Out:
# Test KL loss:  {'KL_loss': tensor(2.2075, device='cuda:0', grad_fn=<DivBackward1>)}
# Best possible KL loss:  {'KL_loss': tensor(1.5364, device='cuda:0')}
# Silly prediction KL loss:  {'KL_loss': tensor(2.6249, device='cuda:0')}

# %%
from test import Accu_Plot

Accu_Plot(log_path = 'logs/EXP1_RF_20_VanillaMNL_LARGE')

# %%
from test import Accu_Plot

Accu_Plot(log_path = 'logs/EXP1_RF_20_AssortmentNN_LARGE')

# %%
from test import Accu_Plot

Accu_Plot(log_path = 'logs/EXP1_RF_20_ResAssortNN_LARGE')
