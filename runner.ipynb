# %%
from run_experiment import mass_run

mass_run()
# Out:
# train loss
# 	train loss       	 (min:    1.838, max:    2.078, cur:    1.838)
# valid loss
# 	valid loss       	 (min:    1.828, max:    1.947, cur:    1.829)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 from run_experiment import mass_run
# ----> 3 mass_run()
#
# File ~/Documents/AssortNN_git/run_experiment.py:123, in mass_run()
#     118 params["data_params"]["test_amount"] = test_amount
#     121 params["exp_params"]["exp_seed"] = seed
# --> 123 runner(params)
#     125 log_path = "logs/"+params["logging_params"]["log_name"]
#     127 ## leave the validation plot
#
# File ~/Documents/AssortNN_git/run_experiment.py:51, in runner(params, demo)
#      36 Te_loader = DataLoader(
#      37     testing_dataset, shuffle=False, batch_size = len(testing_dataset)
#      38 )
#      41 EXP = trainer(
#      42     model,
# ...

# %%
import numpy as np

harvestor =np.load('harvestors/MC20_withAmount_5000.npy', allow_pickle=True)
print(harvestor)
# Out:
# {'VanillaMNL': array([1.99047637, 1.91579604, 1.93800521, 1.97574079, 1.93057859,
#        1.87431848, 1.92191839, 2.01267195, 1.93708801, 1.92238116,
#        1.95921266, 1.9726578 , 1.91867137, 1.96801078, 1.95732653,
#        1.9868207 , 1.9653976 , 1.93908608, 1.97734296, 1.95313871]), 'VanillaMNL_best': array([1.80192769, 1.76731288, 1.77626765, 1.8244251 , 1.77921438,
#        1.73734188, 1.78466344, 1.8885771 , 1.79485452, 1.78482032,
#        1.8119967 , 1.83569682, 1.75564718, 1.82623208, 1.7860074 ,
#        1.82669449, 1.80214393, 1.7799747 , 1.84608185, 1.81626868]), 'AssortmentNN': array([1.89035261, 1.87865913, 1.91084683, 1.90578425, 1.88025498,
#        1.83925378, 1.88526499, 1.97952676, 1.88574946, 1.85842085,
#        1.92459548, 1.95294154, 1.86620915, 1.93291259, 1.92789376,
#        1.91098309, 1.90974844, 1.87371528, 1.92198682, 1.91021109]), 'AssortmentNN_best': array([1.80192769, 1.76731288, 1.77626765, 1.8244251 , 1.77921438,
# ...

# %%
import torch

a = torch.tensor(1.9905, device='cuda:0', requires_grad=True)

a.detach().cpu().item()
# Out:
# 1.9904999732971191
