# %%
from run_experiment import mass_run

mass_run()
# Out:
# train loss
# 	train loss       	 (min:    1.463, max:    2.228, cur:    1.463)
# valid loss
# 	valid loss       	 (min:    2.133, max:    2.245, cur:    2.238)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_53368/484207153.py in <module>
#       1 from run_experiment import mass_run
#       2
# ----> 3 mass_run()
#
# ~\Desktop\EXP1_redo\run_experiment.py in mass_run()
#     106                         params["exp_params"]["exp_seed"] = seed
#     107
# --> 108                         runner(params)
#     109
#     110
#
# ~\Desktop\EXP1_redo\run_experiment.py in runner(params, demo)
#      48     )
#      49
# ---> 50     EXP.run(echo=False)
#      51
#      52
#
# ~\Desktop\EXP1_redo\train.py in run(self, echo)
#     171             valid_accu_collector = []
#     172
# ...
